# %%
import unittest

# 引入刚刚创建的测试模块
from tests.test_collectors import CollectorSmokeTests
from tests.test_pipeline import PipelineSmokeTests

suite = unittest.TestSuite()
suite.addTests(unittest.TestLoader().loadTestsFromTestCase(CollectorSmokeTests))
suite.addTests(unittest.TestLoader().loadTestsFromTestCase(PipelineSmokeTests))

runner = unittest.TextTestRunner(verbosity=2)
result = runner.run(suite)
print("Finished with failures?", not result.wasSuccessful())
